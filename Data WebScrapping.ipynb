# %% [markdown]
# Importing Library

# %%
import yfinance as yf
import pandas as pd
from yahoofinancials import YahooFinancials

# %% [markdown]
# # Web Scrapping

# %%
df = yf.download("SUNPHARMA.NS", start = "2019-01-01", end = "2022-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.drop(["Adj Close",], axis = 1, inplace = True)# Delete a unnecessary column

# %%
df
# Out:
#                   Open        High         Low       Close   Volume
# Date
# 2019-01-01  432.500000  438.799988  429.649994  433.549988  8487116
# 2019-01-02  430.500000  441.200012  429.250000  440.049988  9656878
# 2019-01-03  442.049988  443.600006  434.000000  436.100006  9479511
# 2019-01-04  439.100006  439.899994  432.200012  433.799988  6228693
# 2019-01-07  437.100006  438.000000  429.299988  430.799988  4118235
# ...                ...         ...         ...         ...      ...
# 2021-12-27  784.000000  796.599976  781.150024  794.099976  3598487
# 2021-12-28  796.000000  819.900024  794.200012  815.099976  5477769
# 2021-12-29  822.500000  843.650024  816.500000  838.799988  8748856
# 2021-12-30  836.650024  841.950012  827.349976  834.450012  5179861
# 2021-12-31  834.450012  850.950012  834.000000  845.700012  3346523
#
# [742 rows x 5 columns]

# %%
tickerStrings =["BCYC","SUNPHARMA.NS","DIVISLAB.NS","CIPLA.NS","STAR.NS","DRREDDY.BO","GLAND.NS","BIOCON.NS","TORNTPHARM.NS","AUROPHARMA.NS","CADILAHC.NS","LUPIN.NS","BAJAJHCARE.NS","AJANTPHARM.NS","NATCOPHARM.NS","GLENMARK.NS","PFIZER.NS","ABBOTINDIA.NS","LAURUSLABS.NS","GLAXO.NS","SYNGENE.NS","NVO","REGN","MRNA","VRTX","BNTX","SGEN","GMAB","BGNE","ALNY","RPRX","BMRN","TECH","INCY","ARGX","DNA","UTHR","JAZZ","BHVN","NVAX","ASND","MRTX","SRPT","LEGN","EXEL","ARNA","ARWR","HALO","RARE","BPMC","HCM","IONS","VIR","GLPG","APLS","DNLI","BEAM","CERT","ACAD","ABCM","ALKS","ARVN","MRVI","PTCT","BCRX","CYTX","INSM","SWTX","ABCL","EXAI","IBRX","ADPT","RCUS","NKTR","RXRX","CCXI","TPTX","GBT","VALN","ISEE","RVMD","PRTA","AGIO","ALLO","TIL","BBIO","FGEN","RXDX","SANA","BCYC","ERAS","ATRA","LYEL","MDGL","VERV","ALEC","ENTA","NUVB","ADCT","EDIT","MYOV","NGM","CDXS","IMGN","RGNX","CCCC","AMLX","IMCR","INVA","MOR","PCVX","SEER","REPL","CNTA","ANAB","KURA","DAWN","CRNX","MOLN","SNDX","AVXL","ZEAL","QURE","KZR","ARQT","NUVL","KNSA","DSGN","MGNX","KDNY","ACRS","BLU","PMVP","IMGO","IPSC","MCRB","GOSS","IMVT","MGTX","CRBU","STOK","AKRO","SRRK","GLUE","VTYX","ICVX","RPTX","KPTI","CGEM","EWTX","IDYA","PHVS","OMGA","PRAX","FDMT","TCDA","TNYA","ALXO","AVIR","BLI","RUBY","HUMA","IGMS","CALT","TYRA","ALVR","PHAT","RLMD","BLUE","RLYB","PRLD","ICPT","KNTE","ZYME","GTHX","KRON","THRX","UNCE","VIGL","FNCH","PLRX","GRTS","ATHA","TARS","PRVB","DYN","ORIC","ALLK","IMUX","FUSN","SPRO","YMAB","AMTI","GBIO","NKTX","TSHA","PYXS","VOR","XBIT","OYST","NBTX","ANNX","XLO","OPT","COGT","IOBT","STTK","KMPH","OLMA","CYT","ABOS","SQZ","RAIN","HOWL","AKUS","BMEA","MIST","LVTX","CRTX","INZY","NXTC","SCPH","ANVS"]

for ticker in tickerStrings:
    data = yf.download(ticker, group_by="Ticker",start = "2019-02-09", end = "2022-02-09")
    data['ticker'] = ticker  # add this column because the dataframe doesn't contain a column with the ticker
    data.to_csv(f'ticker_{ticker}.csv')  # ticker_AAPL.csv for example
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
from pathlib import Path

# set the path to the files
p = Path('E:/Internship/Technocolabs')

# find the files; this is a generator, not a list
files = p.glob('ticker_*.csv')

# read the files into a dataframe
df = pd.concat([pd.read_csv(file) for file in files])

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-02-11  8050.000000  8050.000000  7600.000000  7666.399902
# 1    2019-02-12  7700.100098  7787.000000  7640.000000  7754.549805
# 2    2019-02-14  7684.250000  7693.850098  7465.350098  7644.750000
# 3    2019-02-15  7721.200195  7721.200195  7400.000000  7442.450195
# 4    2019-02-18  7500.000000  7500.000000  7211.000000  7264.200195
# ..          ...          ...          ...          ...          ...
# 752  2022-02-02     8.480000     8.570000     7.650000     7.860000
# 753  2022-02-03     7.790000     7.990000     7.400000     7.490000
# 754  2022-02-04     7.470000     8.050000     7.410000     7.950000
# 755  2022-02-07     7.900000     8.330000     7.830000     7.960000
# 756  2022-02-08     7.940000     7.960000     7.500000     7.640000
#
#        Adj Close     Volume         ticker
# 0    7446.035156    21425.0  ABBOTINDIA.NS
# 1    7531.651367     5889.0  ABBOTINDIA.NS
# ...

# %%
df.to_csv("BIO-TECH_STOCK_DATA.CSV")
